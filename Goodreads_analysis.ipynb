# %%
### Complete Notebook Content

Heres your provided notebook content in a formatted view:

```json
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Goodreads Top 1000 Books Analysis\n",
    "This Jupyter Notebook will load the Goodreads Top 1000 Books dataset, display some basic information about the dataset, and visualize the distribution of ratings and the most frequent authors."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 1,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "%matplotlib inline"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 2,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Load the dataset\n",
    "books = pd.read_csv('/path/to/your/good_reads_top_1000_books.csv')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 3,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "First 5 entries in the dataset:\\n",
      "books.head()"
     ]
    }
   ],
   "source": [
    "# Display the first few rows of the dataset\n",
    "print('First 5 entries in the dataset:')\n",
    "print(books.head())"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 4,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Basic information about the dataset\n",
    "books.info()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 5,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Visualization 1: Distribution of Book Ratings\n",
    "plt.figure(figsize=(10, 6))\n",
    "sns.histplot(books['Average Rating'], bins=20, kde=True, color='skyblue')\n",
    "plt.title('Distribution of Book Ratings')\n",
    "plt.xlabel('Rating')\n",
    "plt.ylabel('Frequency')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 6,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Visualization 2: Top 10 Most Frequent Authors\n",
    "plt.figure(figsize=(10, 6))\n",
    "books['Author'].value_counts().head(10).plot(kind='bar', color='salmon')\n",
    "plt.title('Top 10 Most Frequent Authors')\n",
    "plt.xlabel('Author')\n",
    "plt.ylabel('Number of Books')\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "name": "python3",
   "display_name": "Python 3",
   "language": "python"
  },
  "language_info": {
   "name": "python",
   "version": "3.7",
   "mimetype": "text/x-python",
   "file_extension": ".py"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
